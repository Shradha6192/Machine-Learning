# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import time

# %%
df = pd.read_csv("advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
## y should always be related to target means here it is sales
sns.scatterplot(data=df ,x="TV", y="sales")
plt.show()

# %%
sns.scatterplot(data=df ,x="radio", y="sales")
plt.show()

# %%
sns.scatterplot(data=df ,x="newspaper", y="sales")
plt.show()

# %% [markdown]
# # Linear Regression

# %%
##  splitting data into x as tv and y as sales then splitting x as training and testing and same in case of y

X = df[["TV"]]
y = df[["sales"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)
##0.3 means 70% training and 30% testing should be performed & random_states means for same data checking for our purpose

# %%
## an object of linear regression lr
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_ ## theta 0
# Out:
# array([6.92351954])

# %%
## theta 1 slope 1 unit change in tv 0.048  change in sales if 0 is tv then the value will be 6.9 i.e. intercept_
lr.coef_
# Out:
# array([[0.04812204]])

# %%
y_pred = lr.predict(X_test)# y_pred is the predicted o/p

# %%
y_pred
# Out:
# array([[17.06764591],
#        [16.66823297],
#        [11.52879892],
#        [20.4073156 ],
#        [19.1368937 ],
#        [20.57093054],
#        [14.78184893],
#        [15.62398466],
#        [10.32093567],
#        [17.2890073 ],
#        [14.83959538],
#        [10.25356482],
#        [17.25532187],
#        [12.20731971],
#        [17.78947654],
#        [12.97246017],
#        [13.26119242],
#        [20.91259704],
#        [ 8.1554438 ],
#        [17.06283371],
#        [11.75497252],
#        [10.18619396],
#        [ 8.13138278],
#        [12.09182681],
#        [12.35649804],
#        [15.98971218],
#        [ 8.99757953],
#        [18.89628349],
#        [14.95027608],
#        [18.47762173],
#        [18.46799732],
#        [18.2081383 ],
#        [14.12738917],
#        [15.11389102],
#        [18.87703468],
#        [15.82128503],
#        [17.62586159],
#        [13.15051172],
#        [17.35637816],
#        [ 7.86671155],
#        [ 7.55391828],
# ...

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 10.571057434656955

# %%
r2_score(y_test,y_pred)
# Out:
# 0.575061860494331

# %%
plt.figure()
plt.scatter(df["TV"],df["sales"])
plt.plot(X_test,y_pred)
plt.show()

# %%
## same can be done using sns or seaborn plot
plt.figure()
sns.scatterplot(data=df, x="TV", y="sales")
plt.plot(X_test,y_pred,color="red")
plt.show()

# %% [markdown]
# # ## Radio

# %%
X = df[["radio"]]
y = df[["sales"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_ ## theta 0
# Out:
# array([9.44093656])

# %%
lr.coef_
# Out:
# array([[0.1874808]])

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 14.604130559272193

# %%
r2_score(y_test,y_pred)
# Out:
# 0.41293932917162335

# %%
plt.figure()
sns.scatterplot(data=df, x="radio", y="sales")
plt.plot(X_test,y_pred,color="yellow")
plt.show()

# %% [markdown]
# # ## newspaper

# %%
X = df[["newspaper"]]
y = df[["sales"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# array([11.82966888])

# %%
lr.coef_
# Out:
# array([[0.06532045]])

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 25.497452374414927

# %%
r2_score(y_test,y_pred)
# Out:
# -0.024953278429509007

# %%
plt.figure()
sns.scatterplot(data=df, x="newspaper", y="sales")
plt.plot(X_test,y_pred,color="black")
plt.show()

# %% [markdown]
# # Multiple Linear Regression

# %%
X = df[["TV","radio","newspaper"]]
y = df[["sales"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# array([2.93721573])

# %%
lr.coef_
# Out:
# array([[0.04695205, 0.17658644, 0.00185115]])

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.9289249074665737

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9224605706201434

# %% [markdown]
# # Assumptions of Linear Regression

# %%
X = df[["TV","radio"]]
y = df[["sales"]]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# array([2.96476712])

# %%
lr.coef_
# Out:
# array([[0.04697554, 0.17765046]])

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.9147050289721788

# %%
## no multiple colineraity means no indirect dependency NEWSpaper was indirectly affecting there is no difference even if it is removed the r2 score remains same
r2_score(y_test,y_pred)
# Out:
# 0.9230321850256801

# %%
##assumptions
#1.LineaR RELATIONSHIP
#2.there should be HOMOSKEDASTICITY
#3. no MULTICOLINEARITY
#4. graph of RESIDUALS v/s Frequency should be a NORMAL DISTRIBUTION

# %%
## NORMAL DISTRIBUTION GRAPH
residual = y_test - y_pred

# %%
sns.distplot(residual)## negatively skewed 
plt.show()

# %%
## to check whether model is fit for linear regression or not plotting y_pred against residual graph
plt.scatter(y_pred,residual)
plt.show()

# %% [markdown]
# # POLYNOMIAL REGRESSION

# %%
def poly_1(x):
    y = (3*x) + 2
    plt.plot(x,y)

# %%
x=np.arange(-100,100)

# %%
poly_1(x)

# %%
## this curve is for square quadratic eqn [** refers to (raise to power of)]
def poly_2(x):
    y = (4*x**2)+(3*x) + 2
    plt.plot(x,y)

# %%
poly_2(x)

# %%
## this curve is for cube quadratic eqn
def poly_3(x):
    y = (5*x**3)+(4*x**2)+(3*x) + 2
    plt.plot(x,y)

# %%
poly_3(x)

# %%
def poly_5(x):
    y = (6*x**5)+(5*x**3)+(4*x**2)+(3*x) + 2
    plt.plot(x,y)

# %%
poly_5(x)

# %%
## the newspaper radio tv model is nt having linear regression so now we have to check for polynomial regression
from sklearn.preprocessing import PolynomialFeatures

# %%
## till degree of 2 for both TV and radio separartely and 5 theta values from theta 0 to theta 4
pf = PolynomialFeatures(2)

# %%
X = df[["TV","radio"]]

# %%
y=df[["sales"]]

# %%
X_poly = pf.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_poly,y,test_size=0.3,random_state=1)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# array([5.14912311])

# %%
lr.coef_
# Out:
# array([[ 0.        ,  0.05281975,  0.02122044, -0.00011661,  0.00109146,
#          0.00025159]])

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.17238345081004028

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9930704848288281

# %%
residual = y_test - y_pred

# %%
## plotting a histogram
sns.distplot(y_test - y_pred)
plt.show()

# %%
plt.scatter(y_pred,residual)
plt.show()

# %% [markdown]
# # Gradient Descent

# %%
def gradient_descent(x,y):
    n = len(x)
    learning_rate = 0.01 ## step size
    intercept = slope = 0
    iterations = 500## no. of steps
    
    for i in range(iterations):
        
        y_pred = x*slope + intercept
        
        mse = mean_squared_error(y_pred,y)
        
        md = (2/n)*sum(x*(y-y_pred)) 
        bd = (2/n)*sum(y-y_pred) 

        slope = slope + (learning_rate * md)
        intercept = intercept + (learning_rate * bd)
        
        print("slope: ",slope,"\nintercept: ",intercept,"\nmse: ",mse,"iteration: ",i)

# %%
x = np.array([1,2,3,4])
y = np.array([12,15,16,18])

# %%
gradient_descent(x,y)
# Out:
# slope:  0.81
# intercept:  0.305
# mse:  237.25 iteration:  0
# slope:  1.48325
# intercept:  0.5634
# mse:  168.586525 iteration:  1
# slope:  2.0425925
# intercept:  0.7829695000000001
# mse:  120.91901402875001 iteration:  2
# slope:  2.5070551500000002
# intercept:  0.9701804850000001
# mse:  87.82029803799588 iteration:  3
# slope:  2.89248785325
# intercept:  1.1304241178
# mse:  64.83069957627998 iteration:  4
# slope:  3.2120934693725
# intercept:  1.2681912427815
# mse:  48.8557419877316 iteration:  5
# slope:  3.47686988682755
# intercept:  1.3872227444572451
# mse:  37.74823256841967 iteration:  6
# slope:  3.695978266580555
# intercept:  1.4906347952267227
# mse:  30.01827891085195 iteration:  7
# slope:  3.877049786832136
# intercept:  1.5810231859931605
# mse:  24.63207538090276 iteration:  8
# slope:  4.026441159507657
# intercept:  1.6605502329316906
# mse:  20.872285311424125 iteration:  9
# slope:  4.149447473934924
# intercept:  1.731017170297674
# ...

# %%
def gradient_descent(x,y):
    n = len(x)
    learning_rate = 0.000001 ## step size
    intercept = slope = 0
    iterations = 150## no. of steps
    
    for i in range(iterations):
        
        y_pred = x*slope + intercept
        
        mse = mean_squared_error(y_pred,y)
        
        md = (2/n)*sum(x*(y-y_pred)) 
        bd = (2/n)*sum(y-y_pred) 

        slope = slope + (learning_rate * md)
        intercept = intercept + (learning_rate * bd)
        
        print("slope: ",slope,"\nintercept: ",intercept,"\nmse: ",mse,"\niteration: ",i,"\n............")

# %%
## u can keep on increasing iteration or reducing learning_rate and decresing mse value can give a line close to best fit line below 1 value of mse is considered as good 
x= df["TV"]
y= df["sales"]

# %%
gradient_descent(x,y)
# Out:
# slope:  0.0048210834
# intercept:  2.8045000000000003e-05
# mse:  223.71625
# iteration:  0
# ............
# slope:  0.009362963905011536
# intercept:  5.4672135598311e-05
# mse:  201.1456684313534
# iteration:  1
# ............
# slope:  0.013641810902204354
# intercept:  7.996351901403448e-05
# mse:  181.11363206948997
# iteration:  2
# ............
# slope:  0.017672857366246283
# intercept:  0.00010399650712782168
# mse:  163.33462698689567
# iteration:  3
# ............
# slope:  0.02147045408945833
# intercept:  0.00012684397687625487
# mse:  147.55525142903932
# iteration:  4
# ............
# slope:  0.02504812077135626
# intercept:  0.00014857458469740275
# mse:  133.5506041108643
# iteration:  5
# ............
# slope:  0.028418594149460095
# intercept:  0.00016925301095118908
# mse:  121.12107872690622
# iteration:  6
# ............
# slope:  0.03159387334271952
# intercept:  0.0001889401901847232
# mse:  110.08951898759078
# iteration:  7
# ............
# ...

# %%
millis_before = int(round(time.time() * 1000))
gradient_descent(x,y)
millis_after = int(round(time.time() * 1000))
print(millis_after - millis_before)
# Out:
# slope:  0.0048210834
# intercept:  2.8045000000000003e-05
# mse:  223.71625
# iteration:  0
# ............
# slope:  0.009362963905011536
# intercept:  5.4672135598311e-05
# mse:  201.1456684313534
# iteration:  1
# ............
# slope:  0.013641810902204354
# intercept:  7.996351901403448e-05
# mse:  181.11363206948997
# iteration:  2
# ............
# slope:  0.017672857366246283
# intercept:  0.00010399650712782168
# mse:  163.33462698689567
# iteration:  3
# ............
# slope:  0.02147045408945833
# intercept:  0.00012684397687625487
# mse:  147.55525142903932
# iteration:  4
# ............
# slope:  0.02504812077135626
# intercept:  0.00014857458469740275
# mse:  133.5506041108643
# iteration:  5
# ............
# slope:  0.028418594149460095
# intercept:  0.00016925301095118908
# mse:  121.12107872690622
# iteration:  6
# ............
# slope:  0.03159387334271952
# intercept:  0.0001889401901847232
# mse:  110.08951898759078
# iteration:  7
# ............
# ...

# %%
x= df["TV"]
y= df["sales"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state = 1)

# %%
millis_before = int(round(time.time() * 1000))
gradient_descent(x_train,y_train)
millis_after = int(round(time.time() * 1000))
print(millis_after - millis_before)
# Out:
# slope:  0.004658189999999999
# intercept:  2.7582857142857147e-05
# mse:  218.058
# iteration:  0
# ............
# slope:  0.009056759680420561
# intercept:  5.3836038675514286e-05
# mse:  196.9632038362489
# iteration:  1
# ............
# slope:  0.01321017870314044
# intercept:  7.883365253957107e-05
# mse:  178.15427197956492
# iteration:  2
# ............
# slope:  0.017132110278851455
# intercept:  0.00010264567634946644
# mse:  161.3835045219996
# iteration:  3
# ............
# slope:  0.020835456113756094
# intercept:  0.00012533818759186206
# mse:  146.43004271332694
# iteration:  4
# ............
# slope:  0.02433239885120882
# intercept:  0.0001469735809951081
# mse:  133.0969604103141
# iteration:  5
# ............
# slope:  0.02763444214791773
# intercept:  0.00016761077378385378
# mse:  121.20867070119584
# iteration:  6
# ............
# slope:  0.030752448516541794
# intercept:  0.0001873053994940107
# mse:  110.60861355246341
# iteration:  7
# ............
# ...
